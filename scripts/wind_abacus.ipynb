# %%
import xarray as xr
#import seaborn as sns
#import matplotlib.pyplot as plt
import numpy as np
#from pathlib import Path
#import pandas as pd

# %%
### Link of the data
root = "ipfs://QmQArGny3Yt4axj4x8j228rQi7w2f3TsMx4U6bsoNkdQg8"

# %%
ds_wabacus= xr.open_dataset(f"{root}/WindLidar-Abacus/v2.0.zarr",engine="zarr")

# %%
ds_wabacus
# Out:
# <xarray.Dataset> Size: 4GB
# Dimensions:  (time: 3222613, height: 151)
# Coordinates:
#   * time     (time) datetime64[ns] 26MB 2024-08-16T00:00:00.417300224 ... 202...
#   * height   (height) float64 1kB -72.0 24.0 120.0 ... 1.423e+04 1.433e+04
# Data variables:
#     peak     (time, height) float32 2GB ...
#     wind     (time, height) float32 2GB ...
# Attributes: (12/13)
#     author:           Ilya Serikov (ilya.serikov@mpimet.mpg.de)
#     creator_email:    ilya.serikov@mpimet.mpg.de
#     creator_name:     Ilya Serikov
#     featureType:      trajectoryProfile
#     history:          2025-01-30T13:29:01Z: converted to Zarr by Lukas Kluft ...
#     information:      wind lidar data corrected for ship heave, pitch and roll
#     ...               ...
#     location:         Atlantic Ocean
#     platform:         RV METEOR
#     project:          ORCESTRA, BOW-TIE
#     source:           Litra S Abacus wind lidar
#     time_resolution:  1 Hz
# ...

# %%
ds_wabacus= xr.open_dataset(f"{root}/WindLidar-Abacus/v1.0.zarr",engine="zarr")

# %%
ds_wabacus
# Out:
# <xarray.Dataset> Size: 3GB
# Dimensions:  (time: 2567675, height: 151)
# Coordinates:
#   * time     (time) datetime64[ns] 21MB 2024-08-18T00:00:00.433100288 ... 202...
#   * height   (height) float64 1kB -72.0 24.0 120.0 ... 1.423e+04 1.433e+04
# Data variables:
#     peak     (time, height) float32 2GB ...
#     wind     (time, height) float32 2GB ...
# Attributes: (12/13)
#     author:           Ilya Serikov (ilya.serikov@mpimet.mpg.de)
#     creator_email:    ilya.serikov@mpimet.mpg.de
#     creator_name:     Ilya Serikov
#     featureType:      trajectoryProfile
#     history:          2025-01-30T13:26:10Z: converted to Zarr by Lukas Kluft ...
#     information:      wind lidar data corrected for ship heave, pitch and roll
#     ...               ...
#     location:         Atlantic Ocean
#     platform:         RV METEOR
#     project:          ORCESTRA, BOW-TIE
#     source:           Litra S Abacus wind lidar
#     time_resolution:  1 Hz
# ...

# %%
# !conda list | grep fortran
# !conda list | grep scipy
# Out:
# zsh:1: command not found: conda
# zsh:1: command not found: conda

# %%
# !conda
# Out:
# zsh:1: command not found: conda

# %%
# !micromamba
# Out:
# zsh:1: command not found: micromamba

# %%
# !pip uninstall numpy -y
# Out:
# Found existing installation: numpy 2.0.1
# Uninstalling numpy-2.0.1:
#   Successfully uninstalled numpy-2.0.1

# %%
# !pip install numpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 70.2 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scipy 1.13.1 requires numpy<2.3,>=1.22.4, but you have numpy 2.4.1 which is incompatible.
# ...

# %%
# !pip install --upgrade scipy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 100.9 MB/s eta 0:00:0000:01
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# easygems 0.0.8 requires scipy<1.14.0, but you have scipy 1.17.0 which is incompatible.
# ...

# %%
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import numpy as np
#
# File ~/micromamba/envs/my_env/lib/python3.12/site-packages/numpy/__init__.py:112
#     109 from . import _distributor_init
#     111 try:
# --> 112     from numpy.__config__ import show_config
#     113 except ImportError as e:
#     114     if isinstance(e, ModuleNotFoundError) and e.name == "numpy.__config__":
#     115         # The __config__ module itself was not found, so add this info:
#
# File ~/micromamba/envs/my_env/lib/python3.12/site-packages/numpy/__config__.py:4
#       1 # This file is generated by numpy's build process
#       2 # It contains system_info results at the time of building this package.
#       3 from enum import Enum
# ----> 4 from numpy._core._multiarray_umath import (
#       5     __cpu_features__,
#       6     __cpu_baseline__,
# ...

# %%
import xarray as xr
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import xarray as xr
#
# File ~/micromamba/envs/my_env/lib/python3.12/site-packages/xarray/__init__.py:3
#       1 from importlib.metadata import version as _version
# ----> 3 from xarray import coders, groupers, indexes, testing, tutorial, ufuncs
#       4 from xarray.backends.api import (
#       5     load_dataarray,
#       6     load_dataset,
#    (...)
#      12     open_mfdataset,
#      13 )
#      14 from xarray.backends.writers import save_mfdataset
#
# File ~/micromamba/envs/my_env/lib/python3.12/site-packages/xarray/coders.py:6
#       1 """
#       2 This module provides coder objects that encapsulate the
#       3 "encoding/decoding" process.
#       4 """
# ----> 6 from xarray.coding.times import CFDatetimeCoder, CFTimedeltaCoder
# ...
